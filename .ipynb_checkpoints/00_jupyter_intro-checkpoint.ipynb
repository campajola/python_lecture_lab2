# %% [markdown]
# # Introduzione

# %% [markdown]
# In questa lezione vedemo come utilizzare il linguaggio di programmazione Python per effettuare l'analisi dei dati raccolti in laboratorio.
#
# ---
#
# Lo faremo utilizzando i  notebooks Jupyter
#
# <img style="width: 250px;" src="https://jupyter.org/assets/logos/rectanglelogo-greytext-orangebody-greymoons.svg">
#
# Jupyter notebook è un ambiente di sviluppo interattivo che permette di scrivere ed eseguire codice Python con risultati immediati e possibilità di aggiungere documentazione a corredo

# %% [markdown]
# Ci appare come una pagina web nel browser, che ti permette di scrivere codice, testo, ed eseguire le celle.
#
# Ma il ''motore'' del notebook gira localmente sul nostro computer attraverso un Kernel che esegue il codice e manda l'output all'interfaccia web

# %% [markdown]
# ## Come si installa?

# %% [markdown]
# Esistono diverse possibilità per installare Jupiter Notebook sul nostro PC.

# %% [markdown]
# Alcune sono elencate a seguire:
#
# ### Su Anaconda
#
# <img style="width: 500px;" src="https://anaconda.org/static/img/anaconda_org_logo.svg">
#
# 1. Scarica [Anaconda](https://www.anaconda.com/products/distribution) (include Python, Jupyter e molte librerie scientifiche).
# 2. Installa Anaconda seguendo il setup.
# 3. Apri **Anaconda Navigator** → clicca su "Launch" sotto *Jupyter Notebook*.
#    Si aprirà nel browser all’indirizzo: `http://localhost:8888`
#
# ---
#
# ### Su Linux o WLS con pip (se hai già Python)
#
# 1. Apri il terminale
# 2. Esegui: `pip install notebook`
# 3. Poi avvia Jupyter nel Terminale con: `jupyter notebook`
# 4. Si aprirà automaticamente nel browser (oppure puoi aprire manualmente l’indirizzo `http://localhost:8888`).
#
# ---
#
# ### Su VS Code
#
# 1. Installa **Visual Studio Code**.
# 2. Aggiungi l’estensione *Jupyter* di Microsoft.
# 3. Crea un file `.ipynb` o aprine uno esistente → puoi eseguire le celle direttamente da lì.

# %% [markdown]
# ---
# Anche Google fornisce una piattaforma per sviluppare in python:
# - [Google colab](https://colab.research.google.com) è una piattaforma online gratuita che offre un servizio di cloud hosting di Jupyter Notebooks
#
#
#
# <img style="width: 400px;" src="data:image/png;base64,...">

# %% [markdown]
# Colab è fondamentalmente un Jupyter Notebook sul cloud.
#
# ---

# %% [markdown]
# Nota bene: JupyterLab è il successore ufficiale di Notebook Jupyter.
# In confronto a quest’ultimo JupyterLab offre infatti più opzioni per l’interazione con il codice ed il sistema.

# %% [markdown]
# ### Prima di continuare trovate qui un reminder su [python](https://www.python.org/)
#
# - Qui una guida su tutto quello che ci può servire: https://www.w3schools.com/python/

# %% [markdown]
# # Mettiamci all'opera
#
# Possiamo trovare una **guida d'introduzione** ai notebook jupyter [qui](https://jupyter-notebook.readthedocs.io/en/stable/).

# %% [markdown]
# Un notebook jupyter è organizzato in **celle**.
#
# In una cella possiamo sccrivere un blocco di codice e vederne subito i risultati.
#
#
# Nella cella sottostante possiamo digitare:
#
# ```python
# print('Hello world')
# ```
#
# e quando premiamo `SHIFT+Return` tutte le linee nella cella sono interpretate

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# possiamo salvare variabili ed eseguire operazioni

# %%
a = 5
print(a)
# Out:
# 5

# %%
a+a
# Out:
# 10

# %%
a
# Out:
# 5

# %%
# print('Ciao')
# a=5
# print(a) 
# a

# %% [markdown]
# ## Documentazione e testo

# %% [markdown]
# Un'altra cosa interessante è che possiamo integrare la documentazione nel nostro notebook.
#
# Per farlo, selezioniamo una cella e utilizziamo il menu a discesa per cambiare il tipo di cella in `Markdown`. Ora possiamo aggiungere documentazione, utilizzando la formattazione [markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). Ad esempio, usiamo il simbolo di cancelletto per le intestazioni...
#
# # Questo è un grande titolo
#
# ## Questo è un sottotitolo
#
# ### Questo è un sottosottotitolo
#
# Possiamo inserire collegamenti ipertestuali utilizzando parentesi quadre e tonde.

# %% [markdown]
# ## Salvataggio

# %% [markdown]
# Puoi impostare il nome del notebook cliccando sul nome in alto e definendo il nome desiderato. Il notebook viene salvato in un file chiamato nome.ipynb (ipynb sta per 'interactive python notebook'). Puoi salvare il notebook utilizzando il menu File in alto, selezionando Scarica come, ad esempio, puoi salvarlo come uno script Python normale, oppure come un file PDF, pagina web o scaricare direttamente il notebook Python stesso.
